# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from pylab import *
import matplotlib
import matplotlib.pyplot as plt
import copy

# %%
df=pd.read_csv("AdmissionDataset/data.csv")
X = df.drop(['Chance of Admit ','Serial No.'],axis=1)
Y = df['Chance of Admit ']

# %%
X = (X - X.mean())/X.std()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
features=['GRE Score','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research']

# %%
# X_test = (X_test - X_test.mean())/X_test.std()
# X_train = (X_train - X_train.mean())/X_train.std()

# %%
X_train = pd.concat([X_train,Y_train],axis=1)

# %%
alpha = 0.01
iters = 1000

# %%
def mse(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.power((y_true - y_pred),2)

# %%
def gradientDescent(X,y,theta,iters,alpha):
    lamda=0.000000001
    for i in range(iters):
        theta1=copy.deepcopy(theta)
        theta1[0][0]=0
        theta = theta - (alpha/len(X)) * (np.sum(X * (X @ theta.T - y), axis=0)+lamda*theta1)
    
    return theta

# %%
i1=0
for index,row in X_train.iterrows():
#     print(index)
    X_train_1= X_train.drop(X_train.index[i1])
#     print(row)
    X_test1= row[0:7]
    y_test1=row[7]
    X = X_train_1.iloc[:,0:7]
    ones = np.ones([X.shape[0],1])
    X = np.concatenate((ones,X),axis=1)
    ylist = X_train_1.iloc[:,7:8].values
    theta = np.zeros([1,8])
    
    g = gradientDescent(X,ylist,theta,iters,alpha)
    theta=g[0]
    y_pred=[]
    y1=0
    for i in range(0,7):
        y1 = y1 + theta[i+1]*row[i]
    y1=y1+theta[0]
        
    error=mse(y1,y_test1)
    print("Error:- ",error)
    i1=i1+1
# Out:
# Error:-  0.011708241520272207
# Error:-  0.003518056616351315
# Error:-  0.00815185234131091
# Error:-  5.763966389846366e-05
# Error:-  0.0006056206087482284
# Error:-  0.00010679937119232326
# Error:-  0.0006270263635036326
# Error:-  0.010811784249548066
# Error:-  0.005329031421923488
# Error:-  0.00010018985337673877
# Error:-  6.134141384530749e-06
# Error:-  0.0004638603827006154
# Error:-  7.972338234728413e-05
# Error:-  0.0011617998945239998
# Error:-  0.008207344531923405
# Error:-  0.0007118927084464417
# Error:-  0.00013772405441436823
# Error:-  0.02916417952741598
# Error:-  0.05349096591017955
# Error:-  0.0001786128890299704
# Error:-  0.0019302411324722036
# Error:-  0.0005079091287041337
# Error:-  0.0017712302230601523
# Error:-  0.0008515621653945965
# Error:-  0.0005903409734953265
# Error:-  0.04156461748232556
# Error:-  0.0031427497049240655
# Error:-  0.00013096890927506174
# Error:-  0.004913284183922358
# Error:-  0.00014088469133303544
# Error:-  7.188267368660733e-05
# Error:-  0.0019672174618096667
# Error:-  0.022736988105201906
# Error:-  0.0013660948629839974
# Error:-  0.04826125555067494
# Error:-  3.441641596219909e-05
# Error:-  0.0020517694931694924
# Error:-  0.0005484027549765137
# Error:-  0.0011403064031026695
# Error:-  8.860434473959537e-05
# Error:-  0.0002744897330433954
# Error:-  0.0010761497673562157
# Error:-  5.2791262937603226e-05
# Error:-  0.00035395481743616424
# Error:-  0.0031489542713509623
# Error:-  0.0002480523062805437
# Error:-  0.0018443885786019697
# Error:-  0.0009320671123197042
# Error:-  0.0009536783314577773
# Error:-  0.0008742986494866829
# Error:-  8.028076468565487e-05
# Error:-  0.0017181057913444725
# Error:-  0.00028950318275623466
# Error:-  4.972335428979322e-07
# Error:-  0.00010074520381715289
# Error:-  0.0008008711284440351
# Error:-  4.551371253752969e-06
# Error:-  0.002868760981946701
# Error:-  0.0019480417674801111
# Error:-  0.001365264340096905
# Error:-  0.00027026007623907883
# Error:-  0.0016591472115019788
# Error:-  0.0005047158114098328
# Error:-  3.197361630175477e-05
# Error:-  0.01269894483949681
# Error:-  0.002003870662622261
# Error:-  0.015012148778708968
# Error:-  0.0009221710772299842
# Error:-  0.004264259711890089
# Error:-  0.0003879536050947399
# Error:-  0.003224785175327422
# Error:-  0.002537128781398271
# Error:-  0.0012082594650500102
# Error:-  0.00043521354055886
# Error:-  0.0004183135426019763
# Error:-  0.00350674962811408
# Error:-  0.00010530397425782542
# Error:-  0.004473019081527595
# Error:-  0.002553855726390744
# Error:-  0.0022076503875286366
# Error:-  0.00019328131061345475
# Error:-  0.011088591440051828
# Error:-  0.0038042682090131314
# Error:-  0.0012210050634121287
# Error:-  0.0006341457601731854
# Error:-  2.4226182285397564e-06
# Error:-  0.00048740266829699755
# Error:-  0.00010001846976940396
# Error:-  0.0017339004130880907
# Error:-  0.00942479594349918
# Error:-  0.0002629441801662435
# Error:-  0.004812945806850387
# Error:-  0.002152069327585576
# Error:-  0.001093394708430696
# Error:-  0.0002676374442780221
# Error:-  0.0006091815222983058
# Error:-  3.540053921916401e-06
# Error:-  0.024019871947877556
# Error:-  0.00025863103678563026
# Error:-  0.0006879780998873759
# Error:-  0.0006878015476185816
# Error:-  3.082724358389062e-05
# Error:-  2.263211223293526e-05
# Error:-  1.3634821118215384e-05
# Error:-  0.00042675490846492113
# Error:-  0.00026200108692851434
# Error:-  8.457080859344036e-05
# Error:-  0.0009223388116037706
# Error:-  0.0005691985662247685
# Error:-  0.00036393080229291564
# Error:-  0.0001447462921332522
# Error:-  0.0009304193589686363
# Error:-  0.023438059512279452
# Error:-  9.088587021621769e-06
# Error:-  0.0009543476408540314
# Error:-  0.013829522793758285
# Error:-  3.030252036181926e-05
# Error:-  0.010562004726575147
# Error:-  0.0304631993002014
# Error:-  0.001410466051478721
# Error:-  7.029825547547595e-05
# Error:-  3.5576031357057877e-06
# Error:-  0.001897569664756368
# Error:-  2.517687137902043e-05
# Error:-  0.0010375253100761567
# Error:-  0.001402710887203982
# Error:-  0.006423046335942127
# Error:-  0.00199964929577787
# Error:-  1.3197538421053576e-07
# Error:-  0.0345321377292279
# Error:-  2.888900533710888e-06
# Error:-  0.001268738658837638
# Error:-  0.0016124851194780326
# Error:-  0.00010996353684992322
# Error:-  0.0011863861415975594
# Error:-  5.787931610994227e-05
# Error:-  0.0026879832623042184
# Error:-  0.008462783684777736
# Error:-  1.3185171064047337e-05
# Error:-  0.006665220674032488
# Error:-  0.007804151198127483
# Error:-  0.0010148131050389617
# Error:-  0.03281404470484256
# Error:-  5.516602827355636e-05
# Error:-  0.07233209099673678
# Error:-  0.0020558856519619934
# Error:-  0.0009925985082025553
# Error:-  0.0027325692694042483
# Error:-  0.00041424645557160014
# Error:-  0.0004233153666487221
# Error:-  0.0010341010428839908
# Error:-  0.0025596924030317227
# Error:-  0.000378435936118294
# Error:-  0.00046676873008797597
# Error:-  0.02679913154551236
# Error:-  7.557576661568794e-06
# Error:-  1.3223231949608551e-05
# Error:-  0.00033975605208769665
# Error:-  0.0004505686968879532
# Error:-  0.0010610497652750754
# Error:-  0.001883394276671254
# Error:-  0.00025132356887251617
# Error:-  0.0013257889251914057
# Error:-  0.0005151436922806394
# Error:-  7.254793681532483e-05
# Error:-  0.0017590863370617344
# Error:-  0.007329057816628831
# Error:-  0.0026312981457610293
# Error:-  9.362171475649069e-05
# Error:-  0.024541282987486965
# Error:-  0.01477552887411068
# Error:-  0.008780039189339995
# Error:-  0.0007216985330062764
# Error:-  0.0022319635860110817
# Error:-  0.0004520802576416028
# Error:-  0.007137229283145349
# Error:-  3.26968425922047e-05
# Error:-  0.00010801987006331355
# Error:-  0.0017843615362691592
# Error:-  0.002910280120098393
# Error:-  3.889237633371365e-05
# Error:-  0.0022811419704918665
# Error:-  0.008284507765486952
# Error:-  0.012026625210450519
# Error:-  0.00020937030817833675
# Error:-  1.1999134690306674e-05
# Error:-  0.0004866426814958763
# Error:-  0.0019830027128246836
# Error:-  0.0037746243463686437
# Error:-  2.5678893634400877e-05
# Error:-  1.651810731206466e-05
# Error:-  0.0001448421558715845
# Error:-  0.00015787656396669937
# Error:-  0.0021186007374979863
# Error:-  0.005408675532644284
# Error:-  3.796721654551133e-05
# Error:-  0.0012953656313012853
# Error:-  0.005588245408623006
# Error:-  0.0005380361372947734
# Error:-  0.05559685899125817
# Error:-  0.002405819424169153
# Error:-  0.00728686808399322
# Error:-  0.0009428222967156196
# Error:-  0.0006995471331009608
# Error:-  0.0037007910836551125
# Error:-  0.003613769456071829
# Error:-  0.0008747068092537204
# Error:-  0.001713165630935717
# Error:-  0.0002041223794375457
# Error:-  0.002030132692487586
# Error:-  0.007630929903790489
# Error:-  0.002342452755413065
# Error:-  0.002773349646234552
# Error:-  0.01060350038127905
# Error:-  0.0007802709614884368
# Error:-  0.0019143686208614535
# Error:-  0.00017091328842354305
# Error:-  0.0006793874335959814
# Error:-  1.1924595263853502e-06
# Error:-  0.00027642335243824366
# Error:-  6.378572552011095e-05
# Error:-  0.005238399479514656
# Error:-  0.0031075144983760275
# Error:-  0.009020536598851504
# Error:-  0.008329497982101875
# Error:-  0.0025291168242393956
# Error:-  0.0024029088709966316
# Error:-  0.00024670705658647816
# Error:-  0.0002592497549579902
# Error:-  0.0007488230102630679
# Error:-  0.0010337459644578293
# Error:-  3.659105871614957e-05
# Error:-  2.0992973244440642e-06
# Error:-  1.57095292864307e-05
# Error:-  0.006028264841691396
# Error:-  0.00025480619467840306
# Error:-  1.8677542439081887e-05
# Error:-  0.007526751225391199
# Error:-  0.0019431111920275592
# Error:-  0.01268430613028878
# Error:-  0.0002917255484261581
# Error:-  0.0006433097093433179
# Error:-  0.0019868441359523832
# Error:-  0.0003611262854004353
# Error:-  0.005263739906901088
# Error:-  0.010031321111891402
# Error:-  5.3349376365721094e-05
# Error:-  0.00036474531336005983
# Error:-  0.0020404333030760694
# Error:-  0.008639679578962832
# Error:-  6.685811250975323e-05
# Error:-  0.00021450612252511912
# Error:-  1.4636753514350252e-05
# Error:-  0.001942555907795616
# Error:-  0.0028078087131290673
# Error:-  0.0017362198594710594
# Error:-  7.297474148714217e-06
# Error:-  0.006448038602773262
# Error:-  0.00014397321690524616
# Error:-  4.1353010023839795e-11
# Error:-  1.5181110371951062e-06
# Error:-  0.0048176814345677185
# Error:-  0.006390863197378741
# Error:-  0.00441588293271077
# Error:-  0.004765883512847695
# Error:-  5.098975236568945e-06
# Error:-  0.00039400459284175235
# Error:-  0.0004979586979001236
# Error:-  2.5221454096401592e-05
# Error:-  0.00039341357331666623
# Error:-  0.0013910453480336922
# Error:-  0.0191286129395695
# Error:-  0.02003178258946827
# Error:-  0.0005497925474042939
# Error:-  0.000138804843856195
# Error:-  0.0010044404697942687
# Error:-  0.009096474722712536
# Error:-  0.0011903400027816588
# Error:-  0.022893590569374386
# Error:-  0.000597858769550136
# Error:-  0.0056710594375648125
# Error:-  0.0001514907936551272
# Error:-  0.0007129783432485091
# Error:-  3.385801455151466e-05
# Error:-  0.00011676506720781051
# Error:-  0.0009843979699444053
# Error:-  1.4826112081100226e-05
# Error:-  0.00019830610258626558
# Error:-  0.0008567968996423067
# Error:-  0.001707381074268145
# Error:-  0.003188620130013053
# Error:-  0.0008142990269015535
# Error:-  0.007840360125930673
# Error:-  0.0008479747001882573
# Error:-  1.4535202752673447e-06
# Error:-  0.006842070261226597
# Error:-  0.00035735309779735575
# Error:-  6.455606653085538e-05
# Error:-  0.004827627766559881
# Error:-  0.0013844334280034237
# Error:-  0.0001588458600452163
# Error:-  0.004687321574927505
# Error:-  0.01197468333173219
# Error:-  1.758792001106815e-05
# Error:-  0.0011564572871443164
# Error:-  0.020581058894334765
# Error:-  0.0007533399979019286
# Error:-  2.177031588669874e-05
# Error:-  0.005564770258387635
# Error:-  0.053132044394086
# Error:-  0.002542079823405053
# Error:-  0.005070854124933859
# Error:-  0.0006119589755068077
# Error:-  0.0006875281008570245
# Error:-  0.0023487134891781313
# Error:-  0.0007068532992013738
# Error:-  0.0028026139064524563
# Error:-  0.0018959635562054416
# Error:-  0.00016640745883550692
# Error:-  0.00016963792556053318
# Error:-  0.00044306259717060656
# Error:-  3.746841523715177e-05
# Error:-  0.0003507715702542073
# Error:-  0.0006182109833963802
# Error:-  0.0013393107569372596
# Error:-  0.0036561299658995176
# Error:-  0.0011617980182981752
# Error:-  0.0003275143981913368
# Error:-  1.1010743269192956e-05
# Error:-  0.000767385596901984
# Error:-  0.0054427137551358185
# Error:-  3.763404037157999e-05
# Error:-  0.00037972389780307597
# Error:-  0.0004650752407012302
# Error:-  0.019163702339194556
# Error:-  0.00020266894112746977
# Error:-  0.0011458006264404984
# Error:-  0.002946440817702972
# Error:-  0.001148765108289077
# Error:-  0.00046286157380409583
# Error:-  0.0011049018106091717
# Error:-  0.0014696815636930161
# Error:-  0.00515812704258133
# Error:-  0.0010352133025890782
# Error:-  0.004837321721904968
# Error:-  0.013946196112343757
# Error:-  0.00043002301902964486
# Error:-  0.0005084070664434514
# Error:-  0.0013163697381004358
# Error:-  0.0013877105132499986
# Error:-  2.7771625378199393e-05
# Error:-  0.004442571052465485
# Error:-  0.025327001901492917
# Error:-  0.010357535053357183
# Error:-  8.331226438880488e-05
# Error:-  0.00047424792554642684
# Error:-  5.243502572363417e-06
# Error:-  0.00031836841722095686
# Error:-  0.0027209579363828727
# Error:-  0.0002910504455176285
