# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from pylab import *
import matplotlib
import matplotlib.pyplot as plt
import copy

# %%
df=pd.read_csv("AdmissionDataset/data.csv")
X = df.drop(['Chance of Admit ','Serial No.'],axis=1)
Y = df['Chance of Admit ']

# %%
X = (X - X.mean())/X.std()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)
features=['GRE Score','TOEFL Score','University Rating','SOP','LOR ','CGPA','Research']

# %%
# X_test = (X_test - X_test.mean())/X_test.std()
# X_train = (X_train - X_train.mean())/X_train.std()

# %%
X_train = pd.concat([X_train,Y_train],axis=1)

# %%
alpha = 0.01
iters = 1000

# %%
def mse(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.power((y_true - y_pred),2)

# %%
def gradientDescent(X,y,theta,iters,alpha):
    lamda=0.000000001
    for i in range(iters):
        theta1=copy.deepcopy(theta)
        theta1[0][0]=0
        theta = theta - (alpha/len(X)) * (np.sum(X * (X @ theta.T - y), axis=0)+lamda*theta1)
    
    return theta

# %%
i1=0
for index,row in X_train.iterrows():
#     print(index)
    X_train_1= X_train.drop(X_train.index[i1])
#     print(row)
    X_test1= row[0:7]
    y_test1=row[7]
    X = X_train_1.iloc[:,0:7]
    ones = np.ones([X.shape[0],1])
    X = np.concatenate((ones,X),axis=1)
    ylist = X_train_1.iloc[:,7:8].values
    theta = np.zeros([1,8])
    
    g = gradientDescent(X,ylist,theta,iters,alpha)
    theta=g[0]
    y_pred=[]
    y1=0
    for i in range(0,7):
        y1 = y1 + theta[i+1]*row[i]
    y1=y1+theta[0]
        
    error=mse(y1,y_test1)

    print(error)
    i1=i1+1
# Out:
# 4.594840564600946e-05
# 0.0021700551671136477
# 0.0023658899027419553
# 0.004532117124938509
# 0.000832554352103292
# 0.0018184704737666904
# 4.052483417750493e-06
# 3.050935308453315e-05
# 0.00019897171893039684
# 0.0021868606777086133
# 0.00012701698735074202
# 0.0028996434400036927
# 0.0007961675892362014
# 0.003921667057416482
# 9.235941502855555e-05
# 0.00010076610465976044
# 0.006128280463681006
# 0.00016317283588593225
# 0.013377485046466924
# 0.0002693408889361267
# 0.0017327866849281145
# 0.0004570458203124796
# 3.6583883209989375e-05
# 0.000506074169738983
# 0.0019342900148093037
# 0.014286510228792518
# 0.05568852264214752
# 0.0009455371875092711
# 0.009309621428865147
# 0.0002304321432050865
# 0.004996623856690141
# 0.024526056581701823
# 0.00023033016941863407
# 0.0008214146499389517
# 0.002926674050964293
# 0.05608562646687325
# 0.005529601538140854
# 0.005280132639695076
# 9.416924126554399e-05
# 1.3492985011724502e-07
# 2.7380129574021913e-06
# 0.0005576643818528494
# 0.004375391987766365
# 0.0008052789051341799
# 0.001670103526885715
# 0.00017288588526248136
# 0.0038933630149628005
# 0.007907149476661738
# 0.0007883620191640365
# 0.034032807080257806
# 0.0033278770294166275
# 1.3955902880858312e-05
# 0.00016482983262433828
# 0.019495179272473986
# 0.0003331771309591484
# 9.920737766852674e-05
# 0.00012244774152391476
# 3.697773596730938e-05
# 0.0020474134818165104
# 0.0010351378758599891
# 0.014902682863167826
# 0.0035304581680848457
# 0.0006265256431929565
# 0.0017399940876160949
# 3.5583458136397066e-05
# 1.3269047927236567e-05
# 0.007248412515972195
# 0.00019783413441269785
# 0.012010516217753476
# 0.00012358108583841702
# 0.000590248659378517
# 0.005536612120718564
# 9.83932687692573e-06
# 0.0025464524188466195
# 0.002195878763419368
# 0.0011117365167676403
# 0.0010724498208277873
# 0.005353386964180549
